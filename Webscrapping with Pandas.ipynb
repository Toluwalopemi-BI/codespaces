# %%
import pandas as pd

scrapper = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_Nigeria")

scrapper 

for idx, table in enumerate(scrapper) :
    print("*******************************************")
    print(idx)
    print(table)
# Out:
# *******************************************
# 0
#                   Demographics of Nigeria  \
# 0   Population pyramid of Nigeria in 2020
# 1                              Population
# 2                             Growth rate
# 3                              Birth rate
# 4                              Death rate
# 5                         Life expectancy
# 6                                  • male
# 7                                • female
# 8                          Fertility rate
# 9                   Infant mortality rate
# 10                     Net migration rate
# 11                          Age structure
# 12                             0–14 years
# 13                            65 and over
# 14                              Sex ratio
# 15                                  Total
# 16                               At birth
# 17                               Under 15
# 18                            65 and over
# 19                            Nationality
# ...

# %%
scrapper[2]
# Out:
#     Unnamed: 0 Total population  Population aged 0–14 (%)  \
# 0         1950       37 860 000                      41.7
# 1         1955       41 122 000                      41.6
# 2         1960       45 212 000                      41.6
# 3         1965       50 239 000                      41.9
# 4         1970       56 132 000                      42.6
# 5         1975       63 566 000                      43.4
# 6         1980       73 698 000                      44.0
# 7         1985       83 902 000                      45.0
# 8         1990       95 617 000                      44.9
# 9         1995      108 425 000                      44.1
# 10        2000      122 877 000                      43.5
# 11        2005      139 586 000                      43.6
# 12        2010      159 708 000                      44.0
#
#     Population aged 15–64 (%)  Population aged 65+ (%)
# 0                        55.3                      3.0
# ...

# %%
scrapper[1]
# Out:
#     Year       Pop. ±% p.a.
# 0   1000    7000000       —
# 1   1500   11000000  +0.09%
# 2   1900   18920000  +0.14%
# 3   1952   30403305  +0.92%
# 4   1963   54959426  +5.53%
# 5   1991   88992220  +1.74%
# 6   2006  140431790  +3.09%
# 7   2011  162805000  +3.00%
# 8   2016  185960000  +2.70%
# 9   2021  211401000  +2.60%
# 10  2022  224300000  +6.10%

# %%
scrapper[3]
# Out:
#       Age   Population  Percent
# 0   Total  140.431.790   100.00
# 1     0–4   22.594.967    16.09
# 2     5–9   20.005.380    14.25
# 3   10–14   16.135.950    11.49
# 4   15–19   14.899.419    10.61
# 5   20–24   13.435.079     9.57
# 6   25–29   12.211.426     8.70
# 7   30–34    9.467.538     6.74
# 8   35–39    7.331.755     5.22
# 9   40–44    6.456.470     4.60
# 10  45–49    4.591.293     3.27
# 11  50–54    4.249.219     3.03
# 12  55–59    2.066.247     1.47
# 13  60–64    2.450.286     1.74
# 14  65–69    1.151.048     0.82
# 15  70–74    1.264.937     0.95
# 16  75–79      579.838     0.41
# 17  80–84      760.053     0.54
# 18    85+      715.225     0.51
